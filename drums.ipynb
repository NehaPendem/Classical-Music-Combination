# %%
cd drive/MyDrive/Colab\ Notebooks/Nottingham
# Out:
# /content/drive/.shortcut-targets-by-id/1vlaNoCnGsZP6EddDX8VhMkaeZ85qSJO4/Colab Notebooks/Nottingham

# %%
! git init
# Out:
# Reinitialized existing Git repository in /content/drive/.shortcut-targets-by-id/1vlaNoCnGsZP6EddDX8VhMkaeZ85qSJO4/Colab Notebooks/Nottingham/.git/

# %%
# !git remote rm origin

# %%
! git remote add origin https://NehaPendem:pinklumos6@github.com/NehaPendem/Nottingham-Music-Neha.git

# %%
# !git add -A

# %%
# !git config --global user.email “nehapendem6@gmail.com”

# %%
# !git config --global user.name “NehaPendem”

# %%
! git commit -m " test commit"
# Out:
# fatal: cannot exec '.git/hooks/post-commit': Permission denied
# [master 8029178]  test commit
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  delete mode 100644 weights-improvement-55-1.0328-bigger.hdf5

# %%
# !python lstm.py
# Out:
# 2021-04-11 13:03:31.172216: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Parsing midi_songs/jigs57.mid
# Parsing midi_songs/jigs64.mid
# Parsing midi_songs/jigs1.mid
# Parsing midi_songs/jigs3.mid
# Parsing midi_songs/jigs50.mid
# Parsing midi_songs/jigs97.mid
# Parsing midi_songs/jigs84.mid
# Parsing midi_songs/jigs28.mid
# Parsing midi_songs/jigs66.mid
# Parsing midi_songs/jigs30.mid
# Parsing midi_songs/jigs2.mid
# Parsing midi_songs/jigs36.mid
# Parsing midi_songs/jigs24.mid
# Parsing midi_songs/jigs71.mid
# Parsing midi_songs/jigs53.mid
# Parsing midi_songs/jigs15.mid
# Parsing midi_songs/jigs21.mid
# Parsing midi_songs/jigs39.mid
# Parsing midi_songs/jigs35.mid
# Parsing midi_songs/jigs4.mid
# Parsing midi_songs/jigs70.mid
# Parsing midi_songs/jigs54.mid
# Parsing midi_songs/jigs74.mid
# Parsing midi_songs/jigs76.mid
# Parsing midi_songs/jigs56.mid
# Parsing midi_songs/jigs67.mid
# ...

# %%
# !git add -A

# %%
! git commit -m "67 epochs done"
# Out:
# [master d489653] 67 epochs done
#  4 files changed, 0 insertions(+), 0 deletions(-)
#  rewrite weights-improvement-64-0.5860-bigger.hdf5 (99%)
#  rewrite weights-improvement-65-0.5596-bigger.hdf5 (99%)
#  rewrite weights-improvement-66-0.5382-bigger.hdf5 (99%)
#  rewrite weights-improvement-67-0.4904-bigger.hdf5 (99%)

# %%
! git push -u origin master
# Out:
# Uploading LFS objects: 100% (4/4), 173 MB | 0 B/s, done.
# Counting objects: 118, done.
# Delta compression using up to 2 threads.
# ^C

# %%
# !curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.deb.sh | sudo bash
# Out:
# Detected operating system as Ubuntu/bionic.
# Checking for curl...
# Detected curl...
# Checking for gpg...
# Detected gpg...
# Running apt-get update... done.
# Installing apt-transport-https... done.
# Installing /etc/apt/sources.list.d/github_git-lfs.list...done.
# Importing packagecloud gpg key... done.
# Running apt-get update... done.
#
# The repository is setup! You can now install packages.

# %%
! sudo apt-get install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   git-lfs
# 0 upgraded, 1 newly installed, 0 to remove and 34 not upgraded.
# Need to get 6,229 kB of archives.
# After this operation, 14.5 MB of additional disk space will be used.
# Get:1 https://packagecloud.io/github/git-lfs/ubuntu bionic/main amd64 git-lfs amd64 2.13.3 [6,229 kB]
# Fetched 6,229 kB in 1s (11.8 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package git-lfs.
# ...

# %%
! git lfs install
# Out:
# Updated git hooks.
# Git LFS initialized.

# %%
! git lfs track "*.hdf5"
# Out:
# Tracking "*.hdf5"

# %%
! git add .gitattributes

# %%
! git commit -m "my commit"
# Out:
# On branch master
# Changes not staged for commit:
# 	modified:   weights-improvement-64-0.5860-bigger.hdf5
# 	modified:   weights-improvement-65-0.5596-bigger.hdf5
# 	modified:   weights-improvement-66-0.5382-bigger.hdf5
# 	modified:   weights-improvement-67-0.4904-bigger.hdf5
#
# no changes added to commit

# %%
ls -l .git/hooks
# Out:
# total 23
# -rwx------ 1 root root  478 Apr 10 05:00 applypatch-msg.sample*
# -rwx------ 1 root root  896 Apr 10 05:00 commit-msg.sample*
# -rwx------ 1 root root 3327 Apr 10 05:00 fsmonitor-watchman.sample*
# -rwx------ 1 root root  280 Apr 11 06:18 post-checkout*
# -rwx------ 1 root root  276 Apr 11 06:18 post-commit*
# -rwx------ 1 root root  274 Apr 11 06:18 post-merge*
# -rwx------ 1 root root  189 Apr 10 05:00 post-update.sample*
# -rwx------ 1 root root  424 Apr 10 05:00 pre-applypatch.sample*
# -rwx------ 1 root root 1642 Apr 10 05:00 pre-commit.sample*
# -rwx------ 1 root root 1492 Apr 10 05:00 prepare-commit-msg.sample*
# -rwx------ 1 root root  270 Apr 11 06:18 pre-push*
# -rwx------ 1 root root 1348 Apr 10 05:00 pre-push.sample*
# -rwx------ 1 root root 4898 Apr 10 05:00 pre-rebase.sample*
# -rwx------ 1 root root  544 Apr 10 05:00 pre-receive.sample*
# -rwx------ 1 root root 3610 Apr 10 05:00 update.sample*

# %%
! chmod -R 777 .git/hooks
